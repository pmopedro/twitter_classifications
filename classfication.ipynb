# %% [markdown]
# ### Twitter Dataset
# ## 1 Classification

# %%
import pandas as pd
import numpy as np

# %%
result = pd.DataFrame()
desired_columns=['name','username','features','likes_count','retweets_count','replies_count','tweet']
with pd.read_json('twitter_features.json', lines=True, chunksize=20000) as reader:
    reader
    for chunk in reader:
        chunk = chunk[desired_columns]
        result = pd.concat([result, chunk], ignore_index=True)
        print(result.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            20000 non-null  object
#  1   username        20000 non-null  object
#  2   features        20000 non-null  object
#  3   likes_count     20000 non-null  int64
#  4   retweets_count  20000 non-null  int64
#  5   replies_count   20000 non-null  int64
#  6   tweet           20000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            40000 non-null  object
#  1   username        40000 non-null  object
#  2   features        40000 non-null  object
#  3   likes_count     40000 non-null  int64
#  4   retweets_count  40000 non-null  int64
#  5   replies_count   40000 non-null  int64
#  6   tweet           40000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 2.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            60000 non-null  object
#  1   username        60000 non-null  object
#  2   features        60000 non-null  object
#  3   likes_count     60000 non-null  int64
#  4   retweets_count  60000 non-null  int64
#  5   replies_count   60000 non-null  int64
#  6   tweet           60000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 3.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            80000 non-null  object
#  1   username        80000 non-null  object
#  2   features        80000 non-null  object
#  3   likes_count     80000 non-null  int64
#  4   retweets_count  80000 non-null  int64
#  5   replies_count   80000 non-null  int64
#  6   tweet           80000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 4.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            100000 non-null  object
#  1   username        100000 non-null  object
#  2   features        100000 non-null  object
#  3   likes_count     100000 non-null  int64
#  4   retweets_count  100000 non-null  int64
#  5   replies_count   100000 non-null  int64
#  6   tweet           100000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 5.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120000 entries, 0 to 119999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            120000 non-null  object
#  1   username        120000 non-null  object
#  2   features        120000 non-null  object
#  3   likes_count     120000 non-null  int64
#  4   retweets_count  120000 non-null  int64
#  5   replies_count   120000 non-null  int64
#  6   tweet           120000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 6.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140000 entries, 0 to 139999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            140000 non-null  object
#  1   username        140000 non-null  object
#  2   features        140000 non-null  object
#  3   likes_count     140000 non-null  int64
#  4   retweets_count  140000 non-null  int64
#  5   replies_count   140000 non-null  int64
#  6   tweet           140000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 7.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160000 entries, 0 to 159999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            160000 non-null  object
#  1   username        160000 non-null  object
#  2   features        160000 non-null  object
#  3   likes_count     160000 non-null  int64
#  4   retweets_count  160000 non-null  int64
#  5   replies_count   160000 non-null  int64
#  6   tweet           160000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 8.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180000 entries, 0 to 179999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            180000 non-null  object
#  1   username        180000 non-null  object
#  2   features        180000 non-null  object
#  3   likes_count     180000 non-null  int64
#  4   retweets_count  180000 non-null  int64
#  5   replies_count   180000 non-null  int64
#  6   tweet           180000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 9.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            200000 non-null  object
#  1   username        200000 non-null  object
#  2   features        200000 non-null  object
#  3   likes_count     200000 non-null  int64
#  4   retweets_count  200000 non-null  int64
#  5   replies_count   200000 non-null  int64
#  6   tweet           200000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220000 entries, 0 to 219999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            220000 non-null  object
#  1   username        220000 non-null  object
#  2   features        220000 non-null  object
#  3   likes_count     220000 non-null  int64
#  4   retweets_count  220000 non-null  int64
#  5   replies_count   220000 non-null  int64
#  6   tweet           220000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 11.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            240000 non-null  object
#  1   username        240000 non-null  object
#  2   features        240000 non-null  object
#  3   likes_count     240000 non-null  int64
#  4   retweets_count  240000 non-null  int64
#  5   replies_count   240000 non-null  int64
#  6   tweet           240000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 12.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260000 entries, 0 to 259999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            260000 non-null  object
#  1   username        260000 non-null  object
#  2   features        260000 non-null  object
#  3   likes_count     260000 non-null  int64
#  4   retweets_count  260000 non-null  int64
#  5   replies_count   260000 non-null  int64
#  6   tweet           260000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 13.9+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280000 entries, 0 to 279999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            280000 non-null  object
#  1   username        280000 non-null  object
#  2   features        280000 non-null  object
#  3   likes_count     280000 non-null  int64
#  4   retweets_count  280000 non-null  int64
#  5   replies_count   280000 non-null  int64
#  6   tweet           280000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 15.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            300000 non-null  object
#  1   username        300000 non-null  object
#  2   features        300000 non-null  object
#  3   likes_count     300000 non-null  int64
#  4   retweets_count  300000 non-null  int64
#  5   replies_count   300000 non-null  int64
#  6   tweet           300000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 16.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320000 entries, 0 to 319999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            320000 non-null  object
#  1   username        320000 non-null  object
#  2   features        320000 non-null  object
#  3   likes_count     320000 non-null  int64
#  4   retweets_count  320000 non-null  int64
#  5   replies_count   320000 non-null  int64
#  6   tweet           320000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 17.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340000 entries, 0 to 339999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            340000 non-null  object
#  1   username        340000 non-null  object
#  2   features        340000 non-null  object
#  3   likes_count     340000 non-null  int64
#  4   retweets_count  340000 non-null  int64
#  5   replies_count   340000 non-null  int64
#  6   tweet           340000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 18.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360000 entries, 0 to 359999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            360000 non-null  object
#  1   username        360000 non-null  object
#  2   features        360000 non-null  object
#  3   likes_count     360000 non-null  int64
#  4   retweets_count  360000 non-null  int64
#  5   replies_count   360000 non-null  int64
#  6   tweet           360000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 19.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380000 entries, 0 to 379999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            380000 non-null  object
#  1   username        380000 non-null  object
#  2   features        380000 non-null  object
#  3   likes_count     380000 non-null  int64
#  4   retweets_count  380000 non-null  int64
#  5   replies_count   380000 non-null  int64
#  6   tweet           380000 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 20.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382210 entries, 0 to 382209
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            382210 non-null  object
#  1   username        382210 non-null  object
#  2   features        382210 non-null  object
#  3   likes_count     382210 non-null  int64
#  4   retweets_count  382210 non-null  int64
#  5   replies_count   382210 non-null  int64
#  6   tweet           382210 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 20.4+ MB
# None

# %%
result.head()
# Out:
#            name     username  \
# 0  Barack Obama  barackobama
# 1  Barack Obama  barackobama
# 2  Barack Obama  barackobama
# 3  Barack Obama  barackobama
# 4  Barack Obama  barackobama
#
#                                             features  likes_count  \
# 0  [0.032840799999999996, 0.279632999999999, 0.30...          314
# 1  [-0.1898005, 0.23507037500000003, 0.49903625, ...          566
# 2  [-0.094298928571428, 0.136600214285714, 0.4788...          217
# 3  [-0.1626531, 0.21753979999999998, 0.3880757999...          103
# 4  [-0.30785029999999997, 0.2269174, 0.2245550999...           66
#
#    retweets_count  replies_count  \
# 0            1698            111
# 1            2252             98
# 2             748            212
# 3             531             83
# 4             257             46
#
#                                                tweet
# 0  JoeBiden The people I grew up with and my neig...
# 1  VP Biden War should always be the absolute las...
# 2  VP Biden on Iran These are the most crippling ...
# 3  Watch live JoeBiden lays out the ObamaBiden pl...
# 4  Be sure to follow OFADebates during tonights V...

# %%
result.groupby('name').size()
# Out:
# name
# Adam Schiff                      1553
# Al Franken                       4688
# Al Gore                          2232
# Alexandria OcasioCortez          6851
# Amy Klobuchar                   12008
# Andrew Cuomo                    22324
# Andrew Yang                     11087
# Arnold                           4428
# Barack Obama                     8132
# Ben  Candy Carson                2065
# Bernie Sanders                  14201
# Beto ORourke                     6595
# Bill Clinton                      937
# Bloomberg Policy Proposals         13
# Chuck Schumer                   18513
# Cory Booker                     48228
# Donna Brazile                   35426
# Elijah E Cummings                2141
# Elizabeth Warren                14596
# Gabrielle Giffords               3914
# Gov Mike Huckabee               11022
# Hillary Clinton                  9037
# Ilhan Omar                       6996
# James E Clyburn                  3389
# Joe Biden                        6207
# Joe Kennedy III                  4272
# John Kerry                       2259
# Julián Castro                    6212
# Karl Rove                        7236
# Madeleine Albright                797
# Marco Rubio                     11957
# Maxine Waters                    1083
# Mike Pence                       5127
# Mitt Romney                      1639
# Nancy Pelosi                     4464
# Newt Gingrich                   15489
# Nikki Haley                      2383
# Pete Buttigieg                   7562
# President Trump 45 Archived       314
# Ron Paul                         7389
# Sarah Palin                      9188
# Senator Bob Dole                  219
# Senator Rand Paul                9157
# Tammy Duckworth                  8273
# Ted Cruz                        15201
# Vice President Kamala Harris     5406
# dtype: int64

# %%
result.columns
# Out:
# Index(['name', 'username', 'features', 'likes_count', 'retweets_count',
#        'replies_count', 'tweet'],
#       dtype='object')

# %%
politicians = pd.read_csv('../scraper/politicians.csv')
politicians['twitter_account'] = politicians['twitter_acount'].str.lower()
politicians
# Out:
#             politician_name   twitter_acount       party  twitter_account
# 0              Barack Obama      BarackObama    democrat      barackobama
# 1            Bernie Sanders    BernieSanders    democrat    berniesanders
# 2                 Joe Biden         JoeBiden    democrat         joebiden
# 3             Kamala Harris               VP    democrat               vp
# 4     Arnold Schwarzenegger   Schwarzenegger  republican   schwarzenegger
# 5           Hillary Clinton   HillaryClinton    democrat   hillaryclinton
# 6                 Karl Rove         KarlRove  republican         karlrove
# 7          Elizabeth Warren          ewarren    democrat          ewarren
# 8                   Al Gore           algore    democrat           algore
# 9              Nancy Pelosi       TeamPelosi    democrat       teampelosi
# 10          Elijah Cummings      RepCummings    democrat      repcummings
# 11  Alexandra Ocasio-Cortez              AOC    democrat              aoc
# 12       Madeleine Albright        madeleine    democrat        madeleine
# 13            Bill Clinton       BillClinton    democrat      billclinton
# 14             Donald Trump          POTUS45  republican          potus45
# 15       Gabrielle Giffords    GabbyGiffords    democrat    gabbygiffords
# 16              Cory Booker       CoryBooker    democrat       corybooker
# 17           Pete Buttigieg    PeteButtigieg    democrat    petebuttigieg
# 18            Amy klobuchar     amyklobuchar    democrat     amyklobuchar
# 19               John Kerry        JohnKerry    democrat        johnkerry
# 20            Beto O’Rourke      BetoORourke    democrat      betoorourke
# 21               Ben Carson    RealBenCarson  republican    realbencarson
# 22              Andrew Yang       AndrewYang    democrat       andrewyang
# 23            Maxine Waters     MaxineWaters    democrat     maxinewaters
# 24               Ilhan Omar          IlhanMN    democrat          ilhanmn
# 25               Mike Pence       Mike_Pence  republican       mike_pence
# 26          Charles Schumer       SenSchumer    democrat       senschumer
# 27               Al Franken        alfranken    democrat        alfranken
# 28              Adam Schiff       AdamSchiff    democrat       adamschiff
# 29              Mitt Romney       MittRomney  republican       mittromney
# 30    Joseph P. Kennedy III       joekennedy    democrat       joekennedy
# 31            Andrew Cuomo        NYGovCuomo    democrat       nygovcuomo
# 32            Newt Gingrich     newtgingrich  republican     newtgingrich
# 33                 Bob Dole      SenatorDole  republican      senatordole
# 34              Jim Clyburn      WhipClyburn    democrat      whipclyburn
# 35            Mike Huckabee  GovMikeHuckabee  republican  govmikehuckabee
# 36                 Ron Paul          RonPaul  republican          ronpaul
# 37                 Ted Cruz          tedcruz  republican          tedcruz
# 38        Michael Bloomberg    MikeProposals    democrat    mikeproposals
# 39          Tammy Duckworth     SenDuckworth    democrat     senduckworth
# 40            Julian Castro     JulianCastro    democrat     juliancastro
# 41              Sarah Palin    SarahPalinUSA  republican    sarahpalinusa
# 42            Donna Brazile     donnabrazile    democrat     donnabrazile
# 43               Rand Paul          RandPaul  republican         randpaul
# 44              Nikki Haley       NikkiHaley  republican       nikkihaley
# 45              Marco Rubio       marcorubio  republican       marcorubio

# %%
politicians.groupby(by='party').count()
# Out:
#             politician_name  twitter_acount  twitter_account
# party
# democrat                 31              31               31
# republican               15              15               15

# %%
df = pd.merge(politicians, result, left_on='twitter_account', right_on='username')

# %%
df.head(3)
# Out:
#   politician_name twitter_acount     party twitter_account          name  \
# 0    Barack Obama    BarackObama  democrat     barackobama  Barack Obama
# 1    Barack Obama    BarackObama  democrat     barackobama  Barack Obama
# 2    Barack Obama    BarackObama  democrat     barackobama  Barack Obama
#
#       username                                           features  \
# 0  barackobama  [0.032840799999999996, 0.279632999999999, 0.30...
# 1  barackobama  [-0.1898005, 0.23507037500000003, 0.49903625, ...
# 2  barackobama  [-0.094298928571428, 0.136600214285714, 0.4788...
#
#    likes_count  retweets_count  replies_count  \
# 0          314            1698            111
# 1          566            2252             98
# 2          217             748            212
#
#                                                tweet
# 0  JoeBiden The people I grew up with and my neig...
# 1  VP Biden War should always be the absolute las...
# 2  VP Biden on Iran These are the most crippling ...

# %%
df.groupby(by='party').count()
# Out:
#             politician_name  twitter_acount  twitter_account    name  \
# party
# democrat             279396          279396           279396  279396
# republican           102814          102814           102814  102814
#
#             username  features  likes_count  retweets_count  replies_count  \
# party
# democrat      279396    279396       279396          279396         279396
# republican    102814    102814       102814          102814         102814
#
#              tweet
# party
# democrat    279396
# republican  102814

# %%
## creating the icml dataset
l = df.features.tolist()
icml_data = pd.DataFrame(l,columns=[i for i in range(len(df.features[1]))])
icml_data['party'] = df['party'].reset_index().drop(columns='index')
icml_data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.032841  0.279633  0.301100 -0.251599  0.012750  0.166686 -0.330437
# 1 -0.189801  0.235070  0.499036 -0.185174 -0.132197 -0.034101 -0.156481
# 2 -0.094299  0.136600  0.478858 -0.246649  0.073277 -0.161007 -0.434388
# 3 -0.162653  0.217540  0.388076 -0.211040  0.050524  0.109540 -0.337217
# 4 -0.307850  0.226917  0.224555 -0.225014  0.021294  0.132904 -0.063445
#
#           7         8         9  ...       110       111       112       113  \
# 0  0.210326 -0.170756  0.074855  ...  0.000949  0.480000  0.235797  0.475000
# 1  0.200357 -0.180266 -0.044649  ... -0.000652  0.562500  0.242061  0.437500
# 2  0.275694 -0.253582  0.126566  ...  0.000349  0.397959  0.215497  0.464286
# 3  0.112349 -0.174558 -0.045012  ... -0.012203  0.680000  0.198997  0.450000
# 4  0.149862 -0.272753 -0.030819  ...  0.003891  0.620000  0.218174  0.450000
#
#         114  115       116       117       118     party
# 0  0.288314    3  0.900000  2.509892  0.100000  democrat
# 1  0.286411    2  0.875000  2.837649  0.125000  democrat
# 2  0.287938    3  0.285714  1.871197  0.071429  democrat
# 3  0.287228    1  1.000000  3.469719  0.000000  democrat
# 4  0.287228    1  1.000000  3.245893  0.000000  democrat
#
# [5 rows x 120 columns]

# %%
from sklearn.manifold import Isomap, TSNE, MDS, LocallyLinearEmbedding
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_blobs
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.manifold import Isomap, TSNE, MDS, LocallyLinearEmbedding
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['party'] = le.fit_transform(df['party'])

# %%
df['party'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: party, dtype: int64

# %% [markdown]
# ## TF-IDF without SMOTE

# %%
# %%time

X_ = df['tweet']
y_ = df['party']

pipe = Pipeline([('vectorizer', CountVectorizer()),  
                 ('tfidf', TfidfTransformer()), 
                 ('classifier', RandomForestClassifier(n_jobs=5, max_depth=13))])

X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)

classifier = pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.84     92201
#            1       0.00      0.00      0.00     33929
#
#     accuracy                           0.73    126130
#    macro avg       0.37      0.50      0.42    126130
# weighted avg       0.53      0.73      0.62    126130
#
# CPU times: user 40.8 s, sys: 155 ms, total: 41 s
# Wall time: 15.9 s
# /home/pedro/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pedro/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/pedro/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
icml_data['party'].head(2)
# Out:
# 0    democrat
# 1    democrat
# Name: party, dtype: object

# %% [markdown]
# ## ICMLA without SMOTE

# %%
from sklearn import preprocessing
categorical = ['party']  
le = preprocessing.LabelEncoder()
icml_data['party'] = le.fit_transform(icml_data['party']) 
icml_data['party'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: party, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

X_ =  icml_data.iloc[:,0:119]
y_ = icml_data['party']

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier(n_jobs=5, max_depth=13))])

X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)

classifier = pipe.fit(X_train, y_train)

# %%
y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85     92201
#            1       0.84      0.07      0.13     33929
#
#     accuracy                           0.75    126130
#    macro avg       0.79      0.53      0.49    126130
# weighted avg       0.77      0.75      0.66    126130

# %%
pd.Series(pipe[1][1].feature_importances_).sort_values()
# Out:
# 115    0.000227
# 116    0.002076
# 118    0.002889
# 107    0.003694
# 82     0.003712
#          ...
# 15     0.023051
# 114    0.023847
# 68     0.023995
# 45     0.030278
# 108    0.030575
# Length: 119, dtype: float64

# %% [markdown]
# ## TF-idf with SMOTE

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
counter_u = Counter(df['party'])
print('useful:',counter_u)
# Out:
# useful: Counter({0: 279396, 1: 102814})

# %%
oversample = SMOTE()

# %%
pipe = Pipeline([('vectorizer', CountVectorizer()),
                 ('tfidf', TfidfTransformer())])

x_features = pipe.fit_transform(df['tweet'])
X_useful, y_useful = oversample.fit_resample(x_features, df['party'])

# summarize the new class distribution
counter_u = Counter(y_useful)

print(counter_u)

# %%
from sklearn.ensemble import RandomForestClassifier

X_ =  X_useful
y_ = y_useful

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier(n_jobs=5, max_depth=13))])

X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)


classifier = pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## ICMLA with SMOTE

# %%
from collections import Counter
from imblearn.over_sampling import SMOTE
counter_u = Counter(icml_data['party'])
print('useful:',counter_u)
oversample = SMOTE()
# Out:
# useful: Counter({'democrat': 279396, 'republican': 102814})

# %%
counter_u = Counter(icml_data['party'])

print(counter_u)

X_useful, y_useful = oversample.fit_resample(icml_data.iloc[:,0:119], icml_data['party'])

# summarize the new class distribution
counter_u = Counter(y_useful)

print(counter_u)
# Out:
# Counter({'democrat': 279396, 'republican': 102814})

# %%
from sklearn.ensemble import RandomForestClassifier

X_ =  X_useful
y_ = y_useful

pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier(n_jobs=5, max_depth=13))])

X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.33, random_state=42)


classifier = pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## 2 Statistics

# %%
import numpy as np
import pandas as pd
import json 
import imblearn
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/pedro/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def get_part_of_speech_tags(token):
    """Maps POS tags to first character lemmatize() accepts.
    We are focusing on Verbs, Nouns, Adjectives and Adverbs here."""

    tag_dict = {"J": wordnet.ADJ, "N": wordnet.NOUN, "V": wordnet.VERB, "R": wordnet.ADV}

    tag = nltk.pos_tag([token])[0][1][0].upper()
    return tag_dict.get(tag, wordnet.NOUN)

# %%
def string_to_lexical(string):
    """ Returns a DataFrame wht the number of each lexical classes in the given string """
    
    tokenizer = TweetTokenizer()
    token_list = tokenizer.tokenize(string)
    df = pd.DataFrame([get_part_of_speech_tags(token) for token in token_list]).groupby(0).size()
    return df

# %%
relevantColumns= [ 'politician_name', 'party','tweet','likes_count','retweets_count','replies_count']
dataTextAnalysis = df[relevantColumns].dropna()
dataTextAnalysis.head(2)
# Out:
#   politician_name  party                                              tweet  \
# 0    Barack Obama      0  JoeBiden The people I grew up with and my neig...
# 1    Barack Obama      0  VP Biden War should always be the absolute las...
#
#    likes_count  retweets_count  replies_count
# 0          314            1698            111
# 1          566            2252             98

# %%
tokenizer = TweetTokenizer()
token_list = tokenizer.tokenize(dataTextAnalysis['tweet'].values[1])

# %%
def tag_string(s):
    tokenizer = TweetTokenizer()
    token_list = nltk.pos_tag(tokenizer.tokenize(s))
    df = pd.DataFrame(list(zip(*token_list))[1]).groupby(0).size()
    return df

# %%
lexicalsTAG = dataTextAnalysis['tweet'].apply(string_to_lexical)
lexicalsTAG.head()
# Out:
# 0    a     n    r    v
# 0  2.0  18.0  2.0  1.0
# 1  1.0   7.0  1.0  1.0
# 2  1.0  13.0  NaN  2.0
# 3  1.0  12.0  1.0  2.0
# 4  1.0  12.0  NaN  2.0

# %%
lexicalsTAG.columns= ['ADJ','NOUN','VERB','ADV']

# %%
table1 = dataTextAnalysis.join(lexicalsTAG).groupby('party').mean().T
table1.columns=['democrat','republican']
#table1['sum'] = table1['democrat']+table1['republican']
table1
# Out:
#                    democrat   republican
# likes_count     4779.415561  1660.613477
# retweets_count   955.392264   461.093956
# replies_count    277.465468   297.749178
# ADJ                1.764218     1.714204
# NOUN              20.114676    18.141897
# VERB               1.763280     1.627590
# ADV                2.950419     2.631375

# %%
(table1.iloc[-4:]).plot(kind='bar', title='Mean by POS for each category')
# Out:
# <AxesSubplot:title={'center':'Mean by POS for each category'}>

# %% [markdown]
# ## 2.1 Sentiment analysis

# %%
from textblob import TextBlob
sent = pd.DataFrame(columns=['polarity','subjectivity'])
sent['sentiment'] = dataTextAnalysis['tweet'].apply(lambda tweet: TextBlob(tweet).sentiment)

# %%
sent
# Out:
#        polarity subjectivity                                  sentiment
# 0           NaN          NaN                               (0.55, 0.65)
# 1           NaN          NaN                 (0.1, 0.48333333333333334)
# 2           NaN          NaN                                 (0.5, 0.5)
# 3           NaN          NaN                 (0.13636363636363635, 0.5)
# 4           NaN          NaN   (0.3181818181818182, 0.6944444444444444)
# ...         ...          ...                                        ...
# 382205      NaN          NaN                 (0.13636363636363635, 0.5)
# 382206      NaN          NaN                 (0.13636363636363635, 0.5)
# 382207      NaN          NaN                 (0.42, 0.7133333333333334)
# 382208      NaN          NaN  (0.10416666666666667, 0.3333333333333333)
# 382209      NaN          NaN                 (0.0, 0.06666666666666667)
#
# [382210 rows x 3 columns]

# %%
sent = sent['sentiment'].apply(pd.Series)
sent.columns=['polarity','subjectivity']

# %%
data_with_sentiment = sent.join(dataTextAnalysis)
data_with_sentiment.head()
# Out:
#    polarity  subjectivity politician_name  party  \
# 0  0.550000      0.650000    Barack Obama      0
# 1  0.100000      0.483333    Barack Obama      0
# 2  0.500000      0.500000    Barack Obama      0
# 3  0.136364      0.500000    Barack Obama      0
# 4  0.318182      0.694444    Barack Obama      0
#
#                                                tweet  likes_count  \
# 0  JoeBiden The people I grew up with and my neig...          314
# 1  VP Biden War should always be the absolute las...          566
# 2  VP Biden on Iran These are the most crippling ...          217
# 3  Watch live JoeBiden lays out the ObamaBiden pl...          103
# 4  Be sure to follow OFADebates during tonights V...           66
#
#    retweets_count  replies_count
# 0            1698            111
# 1            2252             98
# 2             748            212
# 3             531             83
# 4             257             46

# %%
col=['polarity', 'subjectivity']
data_with_sentiment[col].loc[data_with_sentiment['party']==0].plot.hist( bins=50, title='Distribution by sentiment polarity and subjectiviness for Democrats')
# Out:
# <AxesSubplot:title={'center':'Distribution by sentiment polarity and subjectiviness for Democrats'}, ylabel='Frequency'>

# %%
data_with_sentiment[col].loc[data_with_sentiment['party']==1].plot.hist( bins=50, title='Distribution by sentiment polarity and subjectiviness for Republicans')
# Out:
# ---------------------------------------------------------------
# AttributeError                Traceback (most recent call last)
# <ipython-input-76-df33279b7350> in <module>
# ----> 1 data_with_sentiment[col].loc[data_with_sentiment['party']==1].plot.hist( bins=50, title='Distribution by sentiment polarity and subjectiviness for Republicans',normed=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1294             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295         """
# -> 1296         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1297
#    1298     def kde(self, bw_method=None, ind=None, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in _make_plot(self)
#      90                 kwds["weights"] = weights[:, i]
#      91
# ---> 92             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#      93             self._add_legend_handle(artists[0], label, index=i)
#      94
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in _plot(cls, ax, y, style, bins, bottom, column_num, stacking_id, **kwds)
#      61         bottom = bottom + cls._get_stacked_values(ax, stacking_id, base, kwds["label"])
#      62         # ignore style
# ---> 63         n, bins, patches = ax.hist(y, bins=bins, bottom=bottom, **kwds)
#      64         cls._update_stacker(ax, stacking_id, n)
#      65         return patches
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6888             if patch:
#    6889                 p = patch[0]
# -> 6890                 p.update(kwargs)
#    6891                 if lbl is not None:
#    6892                     p.set_label(lbl)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1060                     func = getattr(self, f"set_{k}", None)
#    1061                     if not callable(func):
# -> 1062                         raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                              f"has no property {k!r}")
#    1064                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
779.415561	1660.613477
retweets_count	955.392264	461.093956
replies_count	277.465468	297.749178
ADJ	1.764218	1.714204
NOUN	20.114676	18.141897
VERB	1.763280	1.627590
ADV	2.950419	2.631375
